# %%
#pandas built in data viz built on top of matplot

# %%
import numpy as np

# %%
import seaborn as sns

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
df1 = pd.read_csv('/Users/navi/Downloads/Refactored_Py_DS_ML_Bootcamp-master 2/07-Pandas-Built-in-Data-Viz/df1',index_col=0)

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2 = pd.read_csv('/Users/navi/Downloads/Refactored_Py_DS_ML_Bootcamp-master 2/07-Pandas-Built-in-Data-Viz/df2')

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df1['A'].hist(bins=30) #calls matplotlib under the hood and can use mlt arguments
# Out:
# <AxesSubplot:>

# %%
df1['A'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df1['A'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df2.plot.area()
# Out:
# <AxesSubplot:>

# %%
df2.plot.area(alpha=0.4)
# Out:
# <AxesSubplot:>

# %%
df2.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df2
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008
# 5  0.286043  0.593465  0.907307  0.637898
# 6  0.430436  0.166230  0.469383  0.497701
# 7  0.312296  0.502823  0.806609  0.850519
# 8  0.187765  0.997075  0.895955  0.530390
# 9  0.908162  0.232726  0.414138  0.432007

# %%
df2.plot.bar(stacked=True)
# Out:
# <AxesSubplot:>

# %%
#good for quick analysis otherwise seaborn better

# %%
df1['A'].plot.hist(bins=50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df1.plot.line(y='B',figsize=(12,3))
# Out:
# <AxesSubplot:>

# %%
df1.plot.line(y='B')
# Out:
# <AxesSubplot:>

# %%
df1.plot.scatter(x='A',y='B',c='C')
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df2.plot.box()
# Out:
# <AxesSubplot:>

# %%
df = pd.DataFrame(np.random.randn(1000,2),columns=['a','b'])

# %%
df.head() #bivariate data
# Out:
#           a         b
# 0  1.099264 -1.043510
# 1  1.340640  0.165214
# 2  0.512666  0.977375
# 3 -1.195903  1.400434
# 4 -0.250764 -0.525450

# %%
df.plot.hexbin(x='a',y='b')
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
df.plot.hexbin(x='a',y='b',gridsize=25)
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
df.plot.hexbin(x='a',y='b',gridsize=25,cmap='coolwarm')
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
df2['a'].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df2.plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# EXERCISE

# %%
df3= pd.read_csv('/Users/navi/Downloads/Refactored_Py_DS_ML_Bootcamp-master 2/07-Pandas-Built-in-Data-Viz/df3')

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       500 non-null    float64
#  1   b       500 non-null    float64
#  2   c       500 non-null    float64
#  3   d       500 non-null    float64
# dtypes: float64(4)
# memory usage: 15.8 KB

# %%
df3.plot.scatter(x='a',y='b',figsize=(12,3),s=50,c='red')
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
df3['a'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df3['a'].hist()
# Out:
# <AxesSubplot:>

# %%
plt.style.use('ggplot')

# %%
df3['a'].plot.hist(bins=20,alpha=0.5)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df3[['a','b']].plot.box()
# Out:
# <AxesSubplot:>

# %%
df3['d'].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df3['d'].plot.kde(lw=5,ls='--')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
#df3.ix[0:30]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/r1/tt0g62xx0276z0xtnhgmnrqw0000gn/T/ipykernel_89243/921862409.py in <module>
# ----> 1 df3.ix[0:30]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'ix'

# %%
df3.iloc[0:30].plot.area()
# Out:
# <AxesSubplot:>

# %%
df3.iloc[0:30].plot.area(alpha=0.5)
# Out:
# <AxesSubplot:>

# %%
f=plt.figure()
df3.iloc[0:30].plot.area(alpha=0.5)
plt.legend(loc='center left',bbox_to_anchor =(1.0,0.5))
plt.show()
